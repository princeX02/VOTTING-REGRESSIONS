# %%
import pandas as pd

# %%
data=pd.read_csv("package.csv")

# %%
data.head(3)
# Out:
#    CGPA  Salary
# 0   5.5      30
# 1   4.4      25
# 2   7.7      40

# %%
x=data.iloc[:,:-1]
y=data["Salary"]

# %%
y
# Out:
# 0     30
# 1     25
# 2     40
# 3     34
# 4     50
# 5     54
# 6     43
# 7     60
# 8     45
# 9     64
# 10    68
# 11    66
# 12    70
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train ,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
lr.score(x_train,y_train)*100,lr.score(x_test,y_test)*100
# Out:
# (83.97075184649783, 94.55872305557087)

# %%
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
dt.score(x_train,y_train)*100,tr.score(x_test,y_test)
# Out:
# (99.76100695735302, 0.9169381107491856)

# %%
svm=SVR()
svm.fit(x_train,y_train)
svm.score(x_train,y_train)*100,sc.score(x_test,y_test)*100
# Out:
# (26.58983216459252, 19.691636706379988)

# %%
from sklearn.ensemble import VotingRegressor

# %%
li=[("lr1",LinearRegression()),("dt",DecisionTreeRegressor()),("svm",SVR())]

# %%
vc=VotingRegressor(li)
vc.fit(x_train,y_train)
# Out:
# VotingRegressor(estimators=[('lr1', LinearRegression()),
#                             ('dt', DecisionTreeRegressor()), ('svm', SVR())])

# %%
vc.score(x_train,y_train)*100,vc.score(x_test,y_test)*100
# Out:
# (86.82110443971305, 82.67577063448361)

# %%
df={"lr":lr.predict(x_test),"dt":dt.predict(x_test),"svm":svm.predict(x_test),"vc":vc.predict(x_test)}

# %%
pd.DataFrame(df)
# Out:
#           lr    dt        svm         vc
# 0  61.456908  60.0  50.144882  57.200597
# 1  59.131555  68.0  49.936057  59.022537
# 2  30.452196  34.0  44.431858  36.294685

# %%
(61.456908+60.0+50.144882)/3
# Out:
# 57.20059666666666
